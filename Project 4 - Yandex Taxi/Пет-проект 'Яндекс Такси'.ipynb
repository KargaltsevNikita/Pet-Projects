# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Выставление-корректных-типов-данных" data-toc-modified-id="Выставление-корректных-типов-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выставление корректных типов данных</a></span></li><li><span><a href="#Удаление-пропусков" data-toc-modified-id="Удаление-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Удаление пропусков</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучим-и-опишем-данные-из-таблицы-df_taxi" data-toc-modified-id="Изучим-и-опишем-данные-из-таблицы-df_taxi-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Изучим и опишем данные из таблицы df_taxi</a></span></li><li><span><a href="#Построим-график-временного-ряда,-скользящую-среднюю-и-скользящее-стандартное-отклонение" data-toc-modified-id="Построим-график-временного-ряда,-скользящую-среднюю-и-скользящее-стандартное-отклонение-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Построим график временного ряда, скользящую среднюю и скользящее стандартное отклонение</a></span></li><li><span><a href="#Построим-график-временного-ряда,-разложенного-на-тренд-и-сезонную-компоненту" data-toc-modified-id="Построим-график-временного-ряда,-разложенного-на-тренд-и-сезонную-компоненту-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Построим график временного ряда, разложенного на тренд и сезонную компоненту</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Подготовим-данные" data-toc-modified-id="Подготовим-данные-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Подготовим данные</a></span></li><li><span><a href="#Обучим-четыре-модели" data-toc-modified-id="Обучим-четыре-модели-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучим четыре модели</a></span></li><li><span><a href="#Выберем-лучшую-модель" data-toc-modified-id="Выберем-лучшую-модель-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выберем лучшую модель</a></span></li></ul></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Анализ моделей</a></span><ul class="toc-item"><li><span><a href="#Оценим-модели" data-toc-modified-id="Оценим-модели-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Оценим модели</a></span></li><li><span><a href="#Проверим-лучшую-модель-на-тестовой-выборке" data-toc-modified-id="Проверим-лучшую-модель-на-тестовой-выборке-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверим лучшую модель на тестовой выборке</a></span></li><li><span><a href="#Сравним-результаты-лучшей-модели-с-прогнозированием-медианным-значением" data-toc-modified-id="Сравним-результаты-лучшей-модели-с-прогнозированием-медианным-значением-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Сравним результаты лучшей модели с прогнозированием медианным значением</a></span></li><li><span><a href="#Сравним-результаты-лучшей-модели-с-прогнозированием-предыдущим-значением" data-toc-modified-id="Сравним-результаты-лучшей-модели-с-прогнозированием-предыдущим-значением-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Сравним результаты лучшей модели с прогнозированием предыдущим значением</a></span></li><li><span><a href="#Определим-важность-различных-признаков" data-toc-modified-id="Определим-важность-различных-признаков-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Определим важность различных признаков</a></span></li><li><span><a href="#Сравним-графики-прогноза-и-реального-значения-кол-ва-заказов" data-toc-modified-id="Сравним-графики-прогноза-и-реального-значения-кол-ва-заказов-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Сравним графики прогноза и реального значения кол-ва заказов</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Загрузка данных

# %%
# Скачиваем нужные библиотеки
# !pip install scikit-learn==1.6
# !pip install phik
# !pip install matplotlib==3.5.0 -q

# %%
# Подключаем нужные библиотеки
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import phik
from sklearn.model_selection import train_test_split
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import TargetEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.metrics import make_scorer
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import TimeSeriesSplit
import statsmodels.api as sm

# %%
# Напишем функцию для считывания данных из csv файла и записывания в датафрейм
def df_read_csv(pth1, pth2):
    if os.path.exists(pth1):
        return pd.read_csv(pth1, index_col=[0], parse_dates=[0])
    elif os.path.exists(pth2):
        return pd.read_csv(pth2, index_col=[0], parse_dates=[0])
    else:
        print('Что-то пошло не так')

# %%
# Считываем данные из csv файла и записываем их в переменную df
df_taxi = df_read_csv('/datasets/taxi.csv', 'https://code.s3.yandex.net/datasets/taxi.csv')

# %%
df_taxi.sort_index(inplace=True)

# %%
df_taxi = df_taxi.resample('1H').sum()

# %%
# Создадим функцию, для отображения нужной информации о датафрейме
def df_info(df):
    display(df.head(10))
    df.info()
    display(df.describe())

# %%
# Отобразим информацию о df_taxi
df_info(df_taxi)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# 2018-03-01 05:00:00           6
# 2018-03-01 06:00:00          12
# 2018-03-01 07:00:00          15
# 2018-03-01 08:00:00          34
# 2018-03-01 09:00:00          69
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  4416 non-null   int64
# dtypes: int64(1)
# memory usage: 69.0 KB
#         num_orders
# count  4416.000000
# mean     84.422781
# std      45.023853
# min       0.000000
# 25%      54.000000
# 50%      78.000000
# 75%     107.000000
# max     462.000000

# %% [markdown]
# После загрузки необходимых файлов, имеем 1 датафрейм и 2 уникальных столбцов с данными.

# %% [markdown]
# В датафрейме `df_taxi` мы сохранили  исторические данные о заказах такси в аэропортах.

# %% [markdown]
# **Описание данных:**
# 1. datetime — разбивка заказов такси по часам
# 2. num_orders — количество заказов

# %% [markdown]
# Необходимо будет заменить тип данных у столбца num_orders для экономии памяти.

# %% [markdown]
# ##  Предобработка данных

# %% [markdown]
# ### Выставление корректных типов данных

# %% [markdown]
# **Преобразуем тип данных int 64 в int 32 для экономии памяти в столбцах:**
# - `num_orders`

# %%
df_taxi['num_orders'] = df_taxi['num_orders'].astype('int32')

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Определим кол-во пропусков в каждом столбце**

# %%
df_taxi.isna().sum()
# Out:
# num_orders    0
# dtype: int64

# %% [markdown]
# Пропуски не обнаружены

# %% [markdown]
# На этапе предобработки данных, нам удалось:
# 1. Выставить корректные типы данных для экономии памяти
# 2. Проверить данные на наличие пропусков

# %% [markdown]
# ## Исследовательский анализ данных

# %%
# Создадим функцию для отображения количественных признаков
def quant_feat(df, col, title, xlabel, ylabel):
    # Отобразим данные в столбце col
    display(df[col].describe())
    
    # Отобразим гистограмму, построенную для столбца col
    plt.figure(figsize=(15,8))
    plt.title(title)
    sns.histplot(df[col]).set(xlabel=xlabel, ylabel=ylabel);
    
    # Отобразим ящик с усами, построенный для столбца col
    plt.figure(figsize=(15,8))
    plt.title(title)
    sns.boxplot(df[col]).set(ylabel=xlabel);

# %% [markdown]
# ### Изучим и опишем данные из таблицы df_taxi

# %%
df_taxi.head(10)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# 2018-03-01 05:00:00           6
# 2018-03-01 06:00:00          12
# 2018-03-01 07:00:00          15
# 2018-03-01 08:00:00          34
# 2018-03-01 09:00:00          69

# %% [markdown]
# **Изучим столбец `datetime`**

# %%
df_taxi.index.min()
# Out:
# Timestamp('2018-03-01 00:00:00', freq='H')

# %%
df_taxi.index.max()
# Out:
# Timestamp('2018-08-31 23:00:00', freq='H')

# %% [markdown]
# **Изучим столбец `num_orders`**

# %%
# Отобразим данные в столбце price
quant_feat(df_taxi, 'num_orders', 'Распределение кол-ва заказов за час', 'Кол-во заказов в час', 'Кол-во таких часов')
# Out:
# count    4416.000000
# mean       84.422781
# std        45.023853
# min         0.000000
# 25%        54.000000
# 50%        78.000000
# 75%       107.000000
# max       462.000000
# Name: num_orders, dtype: float64
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Построим график временного ряда, скользящую среднюю и скользящее стандартное отклонение

# %%
# Построим график
df_taxi['rolling_mean'] = df_taxi.rolling(168).mean()
df_taxi['std'] = df_taxi['num_orders'].rolling(168).std()
df_taxi.plot(figsize=(15,8))
plt.title('График временного ряда, скользящая средняя и скользящее стандартное отклонение')
plt.xlabel('Дата')
plt.ylabel('Кол-во заказов, шт.');

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Есть график временного ряда! </font>

# %% [markdown]
# ### Построим график временного ряда, разложенного на тренд и сезонную компоненту

# %%
# Создадим функцию для отображения графика временного ряда, трендов и сезонности
def time_series(df):
    decomposed = seasonal_decompose(df.num_orders)
    plt.figure(figsize=(6, 8))
    plt.subplot(311)
    decomposed.trend.plot(ax=plt.gca())
    plt.title('Trend')
    plt.subplot(312)
    decomposed.seasonal.plot(ax=plt.gca())
    plt.title('Seasonality')
    plt.subplot(313)
    decomposed.resid.plot(ax=plt.gca())
    plt.title('Residuals')
    plt.tight_layout()

# %% [markdown]
# **Построим график в разрезе дня**

# %%
# Построим график в разрезе одного дня
df_taxi_day = df_taxi.copy()
df_taxi_day = df_taxi_day['2018-03-01 00:00:00' : '2018-03-02 23:00:00']
time_series(df_taxi_day)

# %% [markdown]
# **Построим график в разрезе недели**

# %%
# Построим график в разрезе одной недели
df_taxi_week = df_taxi.copy()
df_taxi_week = df_taxi_week['2018-03-01 00:00:00' : '2018-03-14 23:00:00'].resample('1D').sum()
time_series(df_taxi_week)

# %% [markdown]
# **Построим график в разрезе месяца**

# %%
# Построим график в разрезе одного месяца
df_taxi_month = df_taxi.copy()
df_taxi_month = df_taxi_month['2018-03-01 00:00:00' : '2018-03-31 23:00:00'].resample('1D').sum()
time_series(df_taxi_month)

# %% [markdown]
# **Построим график в разрезе нескольких месяцев**

# %%
# Построим график в разрезе одного месяца
df_taxi_som_month = df_taxi.copy()
df_taxi_som_month = df_taxi_som_month['2018-03-01 00:00:00' : '2018-04-30 23:00:00'].resample('1D').sum()
time_series(df_taxi_som_month)

# %% [markdown]
# **Построим график за весь период**

# %%
# Построим график в разрезе одного месяца
df_taxi_all = df_taxi.copy()
df_taxi_all = df_taxi_all.resample('1D').sum()
time_series(df_taxi_all)

# %% [markdown]
# На этапе исследовательского анализа данных, нам удалось:
# 1. Изучили и описали данные из таблицы df_taxi
#
# По полученым данным, можно сказать:
# - средняя кол-во заказов такси в час - 84
# - В 99% случаев кол-во заказов в час не превышает 187

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Подготовим данные

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.1
m_l = 32
r_m_s = 6
std_s = 24

# %%
# Создадим функцию для генерации признаков
def make_features(data, max_lag, rolling_mean_size, std_size):
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour

    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)
        
    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()
    data['std'] = data['num_orders'].shift().rolling(std_size).std()

# %%
# Вычисляем автокорреляцию
acf_values = sm.tsa.acf(df_taxi['num_orders'], alpha=.05, nlags=32) 

# Строим график результатов
sm.graphics.tsa.plot_acf(df_taxi['num_orders'], alpha=.05, lags=32) 
plt.show()

# %%
make_features(df_taxi, m_l, r_m_s, std_s)

# %%
# Разделение на тренировочную и тестовую выборки
train, test = train_test_split(
    df_taxi,
    shuffle=False,
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE)

# %%
# Удалим пропуски в столбце num_orders
train = train.dropna()

# %%
# Вывод необходимых размерностей
print(train.shape)
print(test.shape)
# Out:
# (3942, 37)
# (442, 37)

# %%
# Разобьем признаки на входящие и целевые
X_train = train.drop(columns='num_orders')
y_train = train['num_orders']
X_test = test.drop(columns='num_orders')
y_test = test['num_orders']

# %%
# Создаём списки с названиями признаков
te_columns = ['dayofweek', 'hour']
num_columns = df_taxi.drop(columns=['dayofweek', 'hour', 'num_orders']).columns.tolist()

# %%
# Создаём пайплайн для подготовки признаков из списка te_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + te
te_pipe = Pipeline(
    [('te', TargetEncoder(target_type='continuous', random_state=RANDOM_STATE))
    ]
    )

# %%
# Создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('te', te_pipe, te_columns),
     ('num', MinMaxScaler(), num_columns),
    ], 
    remainder='passthrough'
)

# %%
# Создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LinearRegression())
])

# %% [markdown]
# ### Обучим четыре модели

# %%
# В списке словарей укажем, какие модели и какие варианты масштабирования собираемся перебрать
param_grid = [
    
    # словарь для модели LGBMRegressor()
    {
        'models': [LGBMRegressor(random_state=RANDOM_STATE)],
        'models__n_estimators': range(10, 100),
        'models__max_depth': range(2, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'] 
    },
    
    # словарь для модели LinearRegression()
    {
        'models': [LinearRegression()],
        #'models__C': range(1, 7),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели RandomForestRegressor()
    {
        'models': [RandomForestRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 15),
        'models__max_features': range(2, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'] 
    },
    
    # словарь для модели DecisionTreeRegressor()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 15),
        'models__max_features': range(2, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'] 
    }
    
]

# %%
# Создаём функцию для оценки качества модели
def root_mean_squared_error(y_true, y_pred):
    diff = y_pred - y_true # находим разницу между прогнозируемыми и наблюдаемыми значениями 
    differences_squared = diff ** 2 # возводим в квадрат
    mean_diff = differences_squared.mean() # находим среднее значение
    rmse_val = np.sqrt(mean_diff) # извлекаем квадратный корень
    return rmse_val

# %%
# Создаём пользовательскую метрику
scorer_rmse = make_scorer(root_mean_squared_error, greater_is_better=False)

# %%
# Переберём разные модели и варианты масштабирования
tscv = TimeSeriesSplit(n_splits=3)

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=tscv,
    scoring=scorer_rmse,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

randomized_search.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/_tags.py:354: FutureWarning: The LGBMRegressor or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %% [markdown]
# ### Выберем лучшую модель

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', -randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('te',
#                                                   Pipeline(steps=[('te',
#                                                                    TargetEncoder(random_state=42,
#                                                                                  target_type='continuous'))]),
#                                                   ['dayofweek', 'hour']),
#                                                  ('num', StandardScaler(),
#                                                   ['rolling_mean', 'std',
#                                                    'lag_1', 'lag_2', 'lag_3',
#                                                    'lag_4', 'lag_5', 'lag_6',
#                                                    'lag_7', 'lag_8', 'lag_9',
# ...

# %% [markdown]
# Для предсказания кол-ва заказов такси на следующий час, мы:
# - собрали пайплайн
# - обучили и сделали прогноз по 4-ем моделям
#
# Наилучший результат показала модель:
# - LGBMRegressor с параметрами max_depth=14, n_estimators=78

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# ### Оценим модели

# %%
# Сохраним 10 лучших результатов в датафрейм и выведим на экран
all_results = pd.DataFrame(randomized_search.cv_results_)
all_results = all_results.sort_values(by='rank_test_score')
all_results = all_results.reset_index(drop=True)
pd.set_option('display.max_colwidth', None)
all_results[['param_models', 'rank_test_score', 'mean_test_score','params']]
# Out:
#                              param_models  rank_test_score  mean_test_score  \
# 0          LGBMRegressor(random_state=42)                1       -26.414371
# 1          LGBMRegressor(random_state=42)                2       -26.444462
# 2          LGBMRegressor(random_state=42)                3       -26.549102
# 3          LGBMRegressor(random_state=42)                4       -26.604547
# 4          LGBMRegressor(random_state=42)                5       -26.635854
# 5          LGBMRegressor(random_state=42)                6       -27.233537
# 6          LGBMRegressor(random_state=42)                7       -27.340283
# 7  RandomForestRegressor(random_state=42)                8       -27.360216
# 8          LGBMRegressor(random_state=42)                9       -27.437778
# 9  DecisionTreeRegressor(random_state=42)               10       -35.835493
#
# ...

# %%
# Выберем лучшие варианты для 3-ех разных моделей
results = pd.DataFrame(randomized_search.cv_results_)
results['model_name'] = results['param_models'].apply(lambda x: x.__class__.__name__)
top_per_model = results.groupby('model_name').apply(lambda x: x.nlargest(1, 'mean_test_score'))
top_per_model
# Out:
#                          mean_fit_time  std_fit_time  mean_score_time  \
# model_name
# DecisionTreeRegressor 4       0.049653      0.032021         0.010723
# LGBMRegressor         5       0.905394      0.162745         0.094662
# RandomForestRegressor 1       0.812445      0.223583         0.020258
#
#                          std_score_time param_preprocessor__num  \
# model_name
# DecisionTreeRegressor 4        0.006037          MinMaxScaler()
# LGBMRegressor         5        0.000519        StandardScaler()
# RandomForestRegressor 1        0.000370          MinMaxScaler()
#
#                          param_models__n_estimators  param_models__max_depth  \
# model_name
# DecisionTreeRegressor 4                         NaN                       12
# LGBMRegressor         5                        78.0                       14
# RandomForestRegressor 1                         NaN                        8
#
#                                                    param_models  \
# ...

# %%
# Построим графики для 3-ех основных параметров для всех моделей и сравним их
top_per_model['mean_test_score'] = -top_per_model['mean_test_score']
fig, axes = plt.subplots(2, 2, figsize=(20, 12))
sns.barplot(data=top_per_model, x='model_name', y='mean_fit_time', ax=axes[0][0]).set(title='Время обучения модели', xlabel='Модель', ylabel='Время, сек.')
sns.barplot(data=top_per_model, x='model_name', y='mean_score_time', ax=axes[0][1]).set(title='Время предсказания модели', xlabel='Модель', ylabel='Время, сек.')
sns.barplot(data=top_per_model, x='model_name', y='mean_test_score', ax=axes[1][0]).set(title='Метрика RMSE для каждой модели', xlabel='Модель', ylabel='Кол-во заказов');
fig.delaxes(axes[1][1])

# %% [markdown]
# Рейтинг моделей:
# 1. LGBMRegressor
#
# - Время обучения - 0.84 сек
# - Время предсказания - 0.03 сек
# - RMSE на кросс-валидации - 26.41
#
#
# 2. RandomForestRegressor
#
# - Время обучения - 0.80 сек
# - Время предсказания - 0.03 сек
# - RMSE на кросс-валидации - 27.36
#
#
# 3. DecisionTreeRegressor
#
# - Время обучения - 0.04 сек
# - Время предсказания - 0.005 сек
# - RMSE на кросс-валидации - 35.83

# %% [markdown]
# Как видно из полученных результатов выше, самой оптимальной моделью с точи зрения времени и точности прогноза является модель LGBMRegressor.
#
# Применим ее на тестовых данных.

# %% [markdown]
# ### Проверим лучшую модель на тестовой выборке

# %%
# Проверим работу модели на тестовой выборке
# Рассчитаем прогноз на тестовых данных
y_test_pred_one = randomized_search.predict(X_test)  
print(f'Метрика RMSE на тестовой выборке при использовании лучшей модели: {root_mean_squared_error(y_test, y_test_pred_one)}')
# Out:
# Метрика RMSE на тестовой выборке при использовании лучшей модели: 39.681620173784225
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/_tags.py:354: FutureWarning: The LGBMRegressor or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %% [markdown]
# ### Сравним результаты лучшей модели с прогнозированием медианным значением

# %%
# Рассчитаем прогноз на тестовых данных
pred_median = np.ones(y_test.shape) * y_train.median() 
print(f'Метрика RMSE на тестовой выборке при прогнозировании медианным значением: {root_mean_squared_error(y_test, pred_median)}')
# Out:
# Метрика RMSE на тестовой выборке при прогнозировании медианным значением: 87.15277582981295

# %% [markdown]
# ### Сравним результаты лучшей модели с прогнозированием предыдущим значением

# %%
# Рассчитаем прогноз на тестовых данных
pred_previous = y_test.shift() 
pred_previous.iloc[0] = y_train.iloc[-1] 
print(f'Метрика RMSE на тестовой выборке при прогнозировании предыдущим значением: {root_mean_squared_error(y_test, pred_previous)}')
# Out:
# Метрика RMSE на тестовой выборке при прогнозировании предыдущим значением: 58.856486242815066

# %% [markdown]
# Как видно из полученных результатов выше, модель LGBMRegressor предсказывает значения лучше, чем медианная модель или модель предыдущих значений.

# %% [markdown]
# ### Определим важность различных признаков

# %%
# Построим график важности различных признаков
plt.figure(figsize=(15,8))
feat_importances = pd.Series(randomized_search.best_estimator_._final_estimator.feature_importances_, index=randomized_search.best_estimator_.feature_names_in_)
feat_importances.nlargest(12).plot(kind='barh')
plt.title('Важность признаков для лучшей модели')
plt.xlabel('Вес признака')
plt.ylabel('Признак');

# %% [markdown]
# Двумя наиболее важными признаками являются:
# 1. `std` - скользящее стандартное отклонение
# 2. `dayofweek` - день недели

# %% [markdown]
# На этапе анализа моделей, нам удалось:
#
# 1. Проанализировать 3 лучшие модели и выбрать из них саму оптимальную - LGBMRegressor
# 2. Проверить работу самой оптимальной модели на тестовой выборке - RMSE = 39.68
# 3. Сравнить результаты оптимальной модели, с моделью медианных предсказаний и предсказаний по предыдущим значениям
# 4. Определить важность различных признаков для оптимальной модели

# %% [markdown]
# ### Сравним графики прогноза и реального значения кол-ва заказов

# %% [markdown]
# **Построим графики в разрезе двух дней**

# %%
test_final = test.copy()
test_final['num_orders_pred'] = y_test_pred_one
test_final = test_final['2018-08-13 00:00:00' : '2018-08-14 23:00:00']
test_final['num_orders'].plot(figsize=(15,8), label='реальность', color='blue')
test_final['num_orders_pred'].plot(figsize=(15,8), label='прогноз', color='red')
plt.legend()
plt.title('Сравнение фактических и предсказанных заказов')
plt.xlabel('Время')
plt.ylabel('Кол-во заказов, шт.')
plt.show()

# %% [markdown]
# **Построим графики в разрезе одного дня**

# %%
test_final = test.copy()
test_final['num_orders_pred'] = y_test_pred_one
test_final = test_final['2018-08-13 00:00:00' : '2018-08-13 23:00:00']
test_final['num_orders'].plot(figsize=(15,8), label='реальность', color='blue')
test_final['num_orders_pred'].plot(figsize=(15,8), label='прогноз', color='red')
plt.legend()
plt.title('Сравнение фактических и предсказанных заказов')
plt.xlabel('Время')
plt.ylabel('Кол-во заказов, шт.')
plt.show()

# %% [markdown]
# По графику можно заметить, что:
# 1. При предсказание пиковых часов с заказами, модель дает предсказания с 'задержкой'
# - На графике первый локальный максимум наблюдается в райное 13 августа в 15:00, модель предсказывает максимум в районе 13 августа в 16:00
#
# 2. Модель пропускает некоторые пиковые значения
# - Например 13 августа в 21:00
#
# 3. Из-за задержек в предсказание максимумов, может произойти наложение - когда по прогнозу должен быть максимум в этот час, в реальности будет минимум
# - На графике такое наложение видно 14 августа в 01:00

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **В процессе исследования, мы:**

# %% [markdown]
# **1. Выгрузили исходные данные в 1 датафрейм**

# %% [markdown]
# **2. Предобработали данные - выставили корректные типы данных, проверили данные на наличие пропусков**

# %% [markdown]
# **3. Провели исследовательский анализ данных**
#
# По полученным данным, можно сделать несколько выводов:
# - средняя кол-во заказов такси в час - 84
# - в 99% случаев кол-во заказов в час не превышает 187

# %% [markdown]
# **4. Собрали пайплайн, обучили и сделали прогноз для 4-ех моделей**
#
# Наилучший результат показала модель:
# - LGBMRegressor с параметрами max_depth=14, n_estimators=78
#
# Рейтинг моделей:
# 1. LGBMRegressor
#
# - Время обучения - 0.84 сек
# - Время предсказания - 0.03 сек
# - RMSE на кросс-валидации - 26.41
#
#
# 2. RandomForestRegressor
#
# - Время обучения - 0.80 сек
# - Время предсказания - 0.03 сек
# - RMSE на кросс-валидации - 27.36
#
#
# 3. DecisionTreeRegressor
#
# - Время обучения - 0.04 сек
# - Время предсказания - 0.005 сек
# - RMSE на кросс-валидации - 35.83

# %% [markdown]
# **5. Выбрали лучшую модель и проверили ее на тестовых данных**
#
# - Метрика RMSE на тестовой выборке при использовании лучшей модели: 39.68
#
# Сравнили работу лучшей модели с моделью медианных предсказаний и моделью предсказаний по предыдущему значению:
# - Метрика RMSE на тестовой выборке при прогнозировании медианным значением: 87.15
# - Метрика RMSE на тестовой выборке при прогнозировании предыдущим значением: 58.85
#
# Определили важность различных признаков - двумя наиболее важными признаками являются:
# 1. `std` - скользящее стандартное отклонение
# 2. `dayofweek` - день недели
#
# Обноружили слабости лучшей модели:
# 1. При предсказание пиковых часов с заказами, модель дает предсказания с 'задержкой'
#
# 2. Модель пропускает некоторые пиковые значения
#
# 3. Из-за задержек в предсказание максимумов, может произойти наложение - когда по прогнозу должен быть максимум в этот час, в реальности будет минимум
